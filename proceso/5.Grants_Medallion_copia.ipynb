# %% [markdown]
# ##Grants

# %%
# %sql
GRANT SELECT ON TABLE catalog_au.bronze.circuits TO `diegoadama@gmail.com`;
GRANT SELECT ON TABLE catalog_au.silver.circuits_transformed TO `diegoadama@gmail.com`;
GRANT SELECT ON TABLE catalog_au.golden.golden_raced_partitioned TO `diegoadama@gmail.com`;

# %%
# %sql
GRANT USE CATALOG ON CATALOG catalog_au TO `diegoadama@gmail.com`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA catalog_au.bronze TO `diegoadama@gmail.com`;
GRANT USE SCHEMA ON SCHEMA catalog_au.silver TO `diegoadama@gmail.com`;
GRANT USE SCHEMA ON SCHEMA catalog_au.golden TO `diegoadama@gmail.com`;

--GRANT USE SCHEMA ON SCHEMA catalog_au.bronze TO `DES`;

# %%
# %sql
GRANT CREATE TABLE ON SCHEMA catalog_au.bronze TO `diegoadama@gmail.com`;
